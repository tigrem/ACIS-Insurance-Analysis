# %%
# Data Analysis and Visualization
#This notebook performs data loading, profiling, visualization, and analysis.

# %%
import os
import pandas as pd
import warnings
import sys
os.chdir(r'D:\10academy\week3\ACIS-Insurance-Analysis')
sys.path.append(os.getcwd()) 
# Import functions from your modularized scripts
from scripts.data_handler import setup_environment, load_data ,DATA_DIR
from scripts.analysis_and_viz import (
    inspect_data,
    get_descriptive_statistics,
    check_data_types,
    check_missing_values,
    plot_numerical_histograms,
    plot_categorical_bar_charts,
    plot_log_claims_boxplot,
    plot_total_claims_by_province,
    plot_total_claims_by_vehicle_type,
    analyze_monthly_trends,
    calculate_and_plot_loss_ratio,
    plot_monthly_claims_trend
)

# %%
# Get the project root directory
project_root = os.path.dirname(os.path.abspath("__file__"))
setup_environment(project_root)

# %%
# Load the data
data = load_data(data_dir=os.path.join(project_root, DATA_DIR))

if data.empty:
    print("Exiting: Data could not be loaded.")
# Out:
# Data loaded successfully from D:\10academy\week3\ACIS-Insurance-Analysis\notebooks/data\MachineLearningRating_v3.txt

# %%
print("\n--- Performing Data Profiling ---")
inspect_data(data)
get_descriptive_statistics(data)
check_data_types(data)
check_missing_values(data)
# Out:
# --- Performing Data Profiling ---
#
# --- Data Head ---
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# 3              Close Corporation    Mr  English  First National Bank
# 4              Close Corporation    Mr  English  First National Bank
#
# ...

# %%
# Define columns for plotting
numerical_cols = ['TotalPremium', 'TotalClaims', 'CustomValueEstimate']
categorical_cols = ['Gender', 'VehicleType', 'Province']

print("\n--- Generating Visualizations ---")
plot_numerical_histograms(data.copy(), numerical_cols)
plot_categorical_bar_charts(data.copy(), categorical_cols)
plot_log_claims_boxplot(data.copy())
plot_total_claims_by_province(data.copy())
plot_total_claims_by_vehicle_type(data.copy())
# Out:
# --- Generating Visualizations ---

# %%
print("\n--- Performing Data Analysis ---")
analyze_monthly_trends(data.copy())
calculate_and_plot_loss_ratio(data.copy())
plot_monthly_claims_trend(data.copy())

print("\nData analysis complete!")
# Out:
# --- Performing Data Analysis ---
# Data analysis complete!
